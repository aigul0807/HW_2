# %%
import numpy as np
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Трехмерные точки и линии**

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
z1 = np.linspace(0, 15, 1000)
y1 = np.cos(z1)
x1 = np.sin(z1)
ax.plot3D(x1, y1, z1, 'green') # линия
z2 = 15 * np.random.random(100)
y2 = np.cos(z2) + 0.1 * np.random.random(100)
x2 = np.sin(z2) + 0.1 * np.random.random(100)

ax.scatter3D(x2, y2, z2, cmap='Greens') # точки
# Out:
# <ipython-input-11-72e0d6cc6831>:11: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter3D(x2, y2, z2, cmap='Greens') # точки

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

z1 = np.linspace(0, 15, 1000)
y1 = np.cos(z1)
x1 = np.sin(z1)

ax.plot3D(x1, y1, z1, 'green') # линия

z2 = 15 * np.random.random(100)
y2 = np.cos(z2) + 0.1 * np.random.random(100)
x2 = np.sin(z2) + 0.1 * np.random.random(100)

ax.scatter3D(x2, y2, z2, cmap='Greens') # точки

def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)
X, Y = np.meshgrid (x, y)
Z = f(X, Y)

ax.contour3D(X, Y, Z, 40, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(60, 45) # угол наклона

ax.scatter3D(X, Y, Z, c=Z, cmap = 'Greens')
ax.plot_wireframe(X, Y, Z)
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')
ax.set_title('Example')

r = np.linspace(0,6,20)
theta = np.linspace(-0.9 * np.pi, 0.8 * np.pi, 40)

R, Theta = np.meshgrid(r, theta)

X = r * np.sin(Theta)
Y = r * np.cos(Theta)

Z = f(X, Y)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')

theta = 2 * np.pi + np.random.random(1000)
r = 6 * np.random.random(1000)

x = r * np.sin(theta)
y = r * np.cos(theta)
z = f(x, y)

ax.scatter(x, y, z, c=z, cmap='viridis')

ax.plot_trisurf(x, y, z, cmap='viridis')
# Out:
# <ipython-input-18-8e78dba9db48>:14: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter3D(x2, y2, z2, cmap='Greens') # точки

# %% [markdown]
# **Каркасный график**

# %%
ax.plot_wireframe(X, Y, Z)

# %% [markdown]
# **Поверхностный график**

# %%
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')
ax.set_title('Example')

r = np.linspace(0,6,20)
theta = np.linspace(-0.9 * np.pi, 0.8 * np.pi, 40)

R, Theta = np.meshgrid(r, theta)

X = r * np.sin(Theta)
Y = r * np.cos(Theta)

Z = f(X, Y)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')

theta = 2 * np.pi + np.random.random(1000)
r = 6 * np.random.random(1000)

x = r * np.sin(theta)
y = r * np.cos(theta)
z = f(x, y)

ax.scatter(x, y, z, c=z, cmap='viridis')

ax.plot_trisurf(x, y, z, cmap='viridis')

# %%
data = np.random.multivariate_normal([0,0], [[5, 2], [2, 2]], size = 2000)
data = pd.DataFrame(data, columns=['x', 'y'])
print(data.head())
# Out:
#           x         y
# 0 -4.000481 -0.899434
# 1  0.249873  1.814031
# 2 -3.446779 -1.197343
# 3  2.201479  3.309341
# 4  3.023848  2.797242

# %%
fig = plt.figure()
plt.hist(data['x'], alpha = 0.5)
plt.hist(data['y'], alpha = 0.5)

fig = plt.figure()
sns.kdeplot(data=data, shade=True)
# Out:
# <ipython-input-21-421d800cd6f1>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, shade=True)
# <Axes: ylabel='Density'>

# %%
iris = sns.load_dataset('iris')
print(iris.head())

sns.pairplot(iris, hue='species', height=2.5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tips = sns.load_dataset('tips')
print(tips.head())

# гистограммы
#grid = sns.FacetGrid(tips, col='sex', row='day', hue='time')
#grid.map(plt.hist, 'tip', bins=np.linspace(0,40,15))

#sns.catplot(data=tips, x='day', y='total_bill', kind='box')

#sns.jointplot(data=tips, x='tip', y='total_bill', kind='hex')

planets = sns.load_dataset('planets')
#print(planets.head())

#sns.catplot(data=planets, x='year', kind='count', hue='method', order=range(2005, 2015))

# %% [markdown]
# **Гистограммы**

# %%
tips = sns.load_dataset('tips')
grid = sns.FacetGrid(tips, col='sex', row='day', hue='time')
grid.map(plt.hist, 'tip', bins=np.linspace(0,40,15))

sns.catplot(data=tips, x='day', y='total_bill', kind='box')

sns.jointplot(data=tips, x='tip', y='total_bill', kind='hex')

planets = sns.load_dataset('planets')
print(planets.head())

sns.catplot(data=planets, x='year', kind='count', hue='method', order=range(2005, 2015))
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %% [markdown]
# **Сравнение числовых данных**
#
# **Числовые пары**

# %%
tips = sns.load_dataset('tips')
print(tips.head())

sns.pairplot(tips)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **Тепловая карта**

# %% [markdown]
# 0 - независимы
#
# 1 - положительная
#
# -1 - отрицательная

# %%
tips_corr = tips[['total_bill', 'tip', 'size']]

sns.heatmap(tips_corr.corr(), cmap='RdBu_r', annot=True, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# **Диаграмма рассеяния**

# %%
tips = sns.load_dataset('tips')
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex')

sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex')

sns.lmplot(data=tips, x='total_bill', y='tip')

sns.relplot(data=tips, x='total_bill', y='tip', hue='sex')

# %% [markdown]
# **Линейный график**

# %%
sns.lineplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# **Сводная диаграмма**

# %%
sns.jointplot(data=tips, x='total_bill', y='tip')

# %% [markdown]
# **Сравнение числовых и категориальных данных**
#
# **Гистограмма**

# %%
sns.barplot(data=tips, x='total_bill', y='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(data=tips, y='total_bill', x='day', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pointplot(data=tips, x='total_bill', y='day', hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# **Ящик 'с усами'**

# %%
fig=plt.figure()
sns.boxplot(data=tips, x='total_bill', y='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# **"Скрипичная" диаграмма**

# %%
fig=plt.figure()
sns.violinplot(data=tips, x='total_bill', y='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# **Одномерная д. рассеяния**

# %%
sns.stripplot(data=tips, y='total_bill', x='day')

plt.show()
